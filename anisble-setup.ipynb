# %%
move the key to cd .ssh
create the key k8s key set appropriate permisson

# %%
mkdir -p ~/ansible
cat > ~/ansible/hosts.ini <<'EOF'
[control_plane]
127.0.0.1 ansible_connection=local

[workers]
10.0.2.11 ansible_user=ubuntu ansible_ssh_private_key_file=~/.ssh/k8s.pem
10.0.3.12 ansible_user=ubuntu ansible_ssh_private_key_file=~/.ssh/k8s.pem
10.0.4.13 ansible_user=ubuntu ansible_ssh_private_key_file=~/.ssh/k8s.pem
EOF
